# %% [markdown]
# <a href="https://colab.research.google.com/github/Samrajah/AER-850-Project-2/blob/main/Project_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 2: YOLOv8 Training
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
from google.colab import drive



drive.mount('/content/gdrive')


# !yolo task=detect mode=train model=yolov8m.pt data=/content/gdrive/MyDrive/data/data.yaml epochs=60 imgsz=900 batch=5

# %%
Image(filename=f"/content/runs/detect/train15/confusion_matrix_normalized.png", width=600)

# %%
Image(filename=f"/content/runs/detect/train15/PR_curve.png", width=600)

# %%
Image(filename=f"/content/runs/detect/train15/P_curve.png", width=600)

# %%
#Step 3: YOLOv8 Evaluation


from PIL import Image
from ultralytics import YOLO

# Load a pretrained YOLOv8n model
model = YOLO('/content/runs/detect/train15/weights/best.pt')

# Run inference
results1 = model('/content/gdrive/MyDrive/data/evaluation/ardmega.jpg')  # results list

# Show the results
for r1 in results1:
    im_array = r.plot()  # plot a BGR numpy array of predictions
    im = Image.fromarray(im_array[..., ::-1])  # RGB PIL image
    im.show()  # show image
    im.save('results1.jpg')  # save image

# Run inference
results2 = model('/content/gdrive/MyDrive/data/evaluation/arduno.jpg')  # results list

# Show the results
for r2 in results2:
    im_array = r2.plot()  # plot a BGR numpy array of predictions
    im = Image.fromarray(im_array[..., ::-1])  # RGB PIL image
    im.show()  # show image
    im.save('results2.jpg')  # save image

# Run inference on
results3 = model('/content/gdrive/MyDrive/data/evaluation/rasppi.jpg')  # results list

# Show the results
for r3 in results3:
    im_array = r3.plot()  # plot a BGR numpy array of predictions
    im = Image.fromarray(im_array[..., ::-1])  # RGB PIL image
    im.show()  # show image
    im.save('results3.jpg')  # save image
# Out:
# image 1/1 /content/gdrive/MyDrive/data/evaluation/ardmega.jpg: 832x928 1 Button, 15 Capacitors, 9 Connectors, 2 Electrolytic Capacitors, 6 ICs, 15 Resistors, 1 Transistor, 64.7ms
# Speed: 6.5ms preprocess, 64.7ms inference, 2.1ms postprocess per image at shape (1, 3, 832, 928)
#
# image 1/1 /content/gdrive/MyDrive/data/evaluation/arduno.jpg: 640x928 15 Capacitors, 7 Connectors, 2 Electrolytic Capacitors, 6 ICs, 1 Pads, 14 Resistors, 48.9ms
# Speed: 4.0ms preprocess, 48.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 928)
#
# image 1/1 /content/gdrive/MyDrive/data/evaluation/rasppi.jpg: 640x928 25 Capacitors, 9 Connectors, 1 Electrolytic Capacitor, 11 ICs, 1 Inductor, 3 Leds, 2 Padss, 15 Resistors, 48.2ms
# Speed: 4.8ms preprocess, 48.2ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 928)
